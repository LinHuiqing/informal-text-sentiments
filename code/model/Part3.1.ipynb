# %%
# Part 3

# %%
# reading a file

def readfile(file):
    with open(file, encoding = 'utf-8') as f:
        
        # sort file into comments, with each comment being an element of the list
        l = f.read().split('\n\n')
        
        # each word-line is then made into an element within each comment element
        l2 = [i.split('\n') for i in l]
        
        # each word in a word line is made the zeroth element of the 2nd nested list, and its respective entity/sentiment label the first element
        for idx, line in enumerate(l2):
            line = [i.split(" ") for i in line]
            l2[idx] = line
        return l2

data = readfile('train')
print(data[0])
# Out:
# [['Welcome', 'O'], ['lunch', 'O'], ['for', 'O'], ['Charlotte', 'B-neutral'], ['and', 'O'], ['Tin', 'B-neutral'], ['2', 'I-neutral'], ['.', 'O'], ['#DellPinoys', 'O'], ['#iworkfordell', 'O'], ['@', 'O'], ['THE', 'B-neutral'], ['CHEVRONS', 'I-neutral'], ['https://t.co/B5SpZKcsWq', 'O']]

# %%
testing = data[0]
testing.insert(0,['START',''])
testing.append(['STOP',''])
print(testing)
# Out:
# [['START', ''], ['Welcome', 'O'], ['lunch', 'O'], ['for', 'O'], ['Charlotte', 'B-neutral'], ['and', 'O'], ['Tin', 'B-neutral'], ['2', 'I-neutral'], ['.', 'O'], ['#DellPinoys', 'O'], ['#iworkfordell', 'O'], ['@', 'O'], ['THE', 'B-neutral'], ['CHEVRONS', 'I-neutral'], ['https://t.co/B5SpZKcsWq', 'O'], ['STOP', '']]

# %%
print(len(testing))
# Out:
# 16

# %%
# count state transitions

def cstDict(data):
    
    # dictionary holding the count of unique transitions from state y_i-1 to y_i, i.e. from a word of a comment to the next
    # e.g. the if the transition 'machine' --> 'learning' is not in the dictionary already, tuple ('machine','learning') is added as a key with value 1
    dictTran = {}
    
    # dictionary holding the count of unique states y_i-1, with STOP not included
    dictY = {}
    
    for comments in data:
        
        # insert a start and stop state to each comment
        comments.insert(0,['START',''])
        comments.append(['STOP',''])

        counter = len(comments)
        
        idx = counter - 1
        idx2 = counter - 2
        
        # adding each state pair (y_i-1, y_i) to dictTran
        while idx >= 0:
            word_lower = comments[idx][0].lower() # make words lower case
            prev_word_lower = comments[idx - 1][0].lower()
            transition = (prev_word_lower, word_lower) # add to tuple
            if transition not in dictTran.keys(): # check if already in dict
                dictTran[transition] = 1
            else:
                dictTran[transition] += 1
            idx -= 1
            
        # adding each state y_i-1 to dictY
        while idx2 >= 0:
            prev_word_lower = comments[idx2][0].lower() # make words lower case
            if prev_word_lower not in dictY.keys(): # check if already in dict
                dictY[prev_word_lower] = 1
            else:
                dictY[prev_word_lower] += 1
            idx2 -= 1
            
    return dictTran, dictY

def cst(yi_1, yi):
    
    # get data from cstDict
    compare_tran, compare_yi_1 = cstDict(data)
    
    # change parameters to lower case
    yi = yi.lower()
    yi_1 = yi_1.lower()
    
    # add parameters to tuple to compare in dictionary
    tranKey = (yi_1, yi)
    
    # numerator and denominator
    num = compare_tran[tranKey]
    denom = compare_yi_1[yi_1]
    
    # compute probability
    prob = num/denom * 100
    prob_round = round(prob, 5)
    output = "The probability of '" + str(yi) + "' appearing after '" + str(yi_1) + "' is: " + str(prob_round) + "%"
    return output

# %%
a = cstDict(data)
a
# Out:
# ({('https://t.co/b5spzkcswq', 'stop'): 1,
#   ('chevrons', 'https://t.co/b5spzkcswq'): 1,
#   ('the', 'chevrons'): 2,
#   ('@', 'the'): 105,
#   ('#iworkfordell', '@'): 1,
#   ('#dellpinoys', '#iworkfordell'): 1,
#   ('.', '#dellpinoys'): 1,
#   ('2', '.'): 14,
#   ('tin', '2'): 1,
#   ('and', 'tin'): 1,
#   ('charlotte', 'and'): 1,
#   ('for', 'charlotte'): 1,
#   ('lunch', 'for'): 1,
#   ('welcome', 'lunch'): 1,
#   ('start', 'welcome'): 14,
#   ('stop', 'start'): 18560,
#   ('https://t.co/fbbt0aqlts', 'stop'): 2,
#   ('singapore', 'https://t.co/fbbt0aqlts'): 2,
#   ('in', 'singapore'): 4714,
#   ('rooms', 'in'): 4,
#   ('function', 'rooms'): 2,
#   ('virgo', 'function'): 2,
#   ('at', 'virgo'): 2,
#   ("i'm", 'at'): 6262,
#   ('start', "i'm"): 6335,
#   ('https://t.co/uxwpuz3w3j', 'stop'): 1,
#   ('singapore', 'https://t.co/uxwpuz3w3j'): 1,
#   ('supermarket', 'in'): 6,
#   ('prime', 'supermarket'): 3,
#   ('at', 'prime'): 3,
#   ('bitch', 'stop'): 6,
#   ('a', 'bitch'): 6,
#   ('be', 'a'): 85,
#   ('dont', 'be'): 7,
#   ('pls', 'dont'): 3,
#   ('laptop', 'pls'): 1,
#   ('finally', 'laptop'): 1,
#   ('urgh', 'finally'): 1,
#   ('start', 'urgh'): 1,
#   ('️', 'stop'): 56,
#   ('☺', '️'): 59,
#   ('️', '☺'): 11,
#   ('!', '☺'): 8,
#   ('!', '!'): 818,
#   ('care', '!'): 4,
#   ('take', 'care'): 19,
#   ('.', 'take'): 6,
#   ('you', '.'): 38,
#   ('bless', 'you'): 10,
#   ('god', 'bless'): 13,
#   ('may', 'god'): 2,
#   ('and', 'may'): 4,
#   ('ahead', 'and'): 2,
#   ('day', 'ahead'): 3,
#   ('blessed', 'day'): 1,
#   ('a', 'blessed'): 5,
#   ('have', 'a'): 82,
#   ('!', 'have'): 12,
#   ('aman', '!'): 1,
#   ('birthday', 'aman'): 1,
#   ('happy', 'birthday'): 104,
#   ('@hersheyyyss', 'happy'): 1,
#   ('start', '@hersheyyyss'): 2,
#   ('#supportzakirnaik', 'stop'): 2,
#   ('.', '#supportzakirnaik'): 1,
#   ('knowledge', '.'): 3,
#   ('great', 'knowledge'): 2,
#   ('and', 'great'): 4,
#   ('speech', 'and'): 2,
#   ('his', 'speech'): 2,
#   ('with', 'his'): 9,
#   ('world', 'with'): 5,
#   ('the', 'world'): 46,
#   ('around', 'the'): 15,
#   ('peace', 'around'): 2,
#   ('spread', 'peace'): 2,
#   ('he', 'spread'): 2,
#   (',', 'he'): 16,
#   ('speaker', ','): 2,
#   ('great', 'speaker'): 2,
#   ('scholar', 'and'): 2,
#   ('great', 'scholar'): 2,
#   ('a', 'great'): 95,
#   ('naik', 'a'): 2,
#   ('dr.zakir', 'naik'): 1,
#   ('start', 'dr.zakir'): 1,
#   ('telegram', 'stop'): 2,
#   ('on', 'telegram'): 1,
#   ('stickers', 'on'): 1,
#   ('porn', 'stickers'): 1,
#   ('with', 'porn'): 1,
#   ('me', 'with'): 7,
#   ('spam', 'me'): 1,
#   ('someone', 'spam'): 1,
#   ('basket', 'someone'): 1,
#   ('start', 'basket'): 1,
#   ('https://t.co/9uzwwx0dog', 'stop'): 1,
#   ('singapore', 'https://t.co/9uzwwx0dog'): 1,
#   ('e4', 'in'): 1,
#   ('gate', 'e4'): 1,
#   ('at', 'gate'): 16,
#   ('https://t.co/xsz0rrdgdg', 'stop'): 2,
#   (')', 'https://t.co/xsz0rrdgdg'): 2,
#   ('@amalinaaaaar', ')'): 2,
#   ('/', '@amalinaaaaar'): 2,
#   ('w', '/'): 1124,
#   ('johor', 'w'): 162,
#   (',', 'johor'): 1233,
#   ('gudang', ','): 69,
#   ('pasir', 'gudang'): 79,
#   ('in', 'pasir'): 90,
#   ('hut', 'in'): 8,
#   ('pizza', 'hut'): 11,
#   ('@', 'pizza'): 5,
#   ('(', '@'): 924,
#   ('!', '('): 100,
#   ('time', '!'): 19,
#   ('lunch', 'time'): 3,
#   ('start', 'lunch'): 39,
#   ('https://t.co/qwvhr7uri2', 'stop'): 2,
#   ('singapore', 'https://t.co/qwvhr7uri2'): 2,
#   (')', 'in'): 446,
#   ('west', ')'): 6,
#   ('(', 'west'): 7,
#   ('airbase', '('): 2,
#   ('changi', 'airbase'): 2,
#   ('at', 'changi'): 87,
#   ('https://t.co/vfsfoerft5', 'stop'): 1,
#   ('singapore', 'https://t.co/vfsfoerft5'): 1,
#   ('5', 'in'): 8,
#   ('district', '5'): 2,
#   ('at', 'district'): 4,
#   ('https://t.co/exlo143gqz', 'stop'): 1,
#   ('airfield', 'https://t.co/exlo143gqz'): 1,
#   ('sakra', 'airfield'): 2,
#   ('at', 'sakra'): 2,
#   ('https://t.co/pfhwmm5o8p', 'stop'): 1,
#   ('…', 'https://t.co/pfhwmm5o8p'): 1,
#   ('most', '…'): 1,
#   ("singapore's", 'most'): 1,
#   ('of', "singapore's"): 2,
#   ('one', 'of'): 71,
#   ('is', 'one'): 10,
#   ('prvacki', 'is'): 1,
#   (')', 'prvacki'): 1,
#   ('2006', ')'): 1,
#   ('(', '2006'): 1,
#   ('linen', '('): 1,
#   ('on', 'linen'): 1,
#   ('acrylic', 'on'): 1,
#   ('|', 'acrylic'): 1,
#   ('building', '|'): 1,
#   ("prvacki's", 'building'): 1,
#   ('milenko', "prvacki's"): 1,
#   ('start', 'milenko'): 1,
#   ('https://t.co/ompqrkvgbe', 'stop'): 2,
#   ('johor', 'https://t.co/ompqrkvgbe'): 2,
#   ('masai', ','): 111,
#   ('in', 'masai'): 119,
#   ('masai', 'in'): 5,
#   ('centre', 'masai'): 5,
#   ('ict', 'centre'): 5,
#   ('@', 'ict'): 5,
#   ('cafe', '@'): 9,
#   ('internet', 'cafe'): 6,
#   ('at', 'internet'): 5,
#   ('already', 'stop'): 6,
#   ('sian', 'already'): 1,
#   ('then', 'sian'): 1,
#   ('play', 'then'): 1,
#   ('you', 'play'): 2,
#   ('awhile', 'you'): 2,
#   ('after', 'awhile'): 1,
#   ('like', 'after'): 1,
#   ('go', 'like'): 2,
#   ('pokemon', 'go'): 143,
#   ('than', 'pokemon'): 1,
#   ('better', 'than'): 14,
#   ('is', 'better'): 6,
#   ('pokemon', 'is'): 4,
#   ('of', 'pokemon'): 3,
#   ('version', 'of'): 4,
#   ('ds', 'version'): 1,
#   ('/', 'ds'): 1,
#   ('gameboy', '/'): 1,
#   ('the', 'gameboy'): 1,
#   ('actually', 'the'): 4,
#   ('start', 'actually'): 8,
#   ('https://t.co/pksefgq5az', 'stop'): 1,
#   ('tho', 'https://t.co/pksefgq5az'): 1,
#   ('honestly', 'tho'): 1,
#   ('but', 'honestly'): 1,
#   ('sorry', 'but'): 2,
#   ('ya', 'sorry'): 1,
#   ('house', 'ya'): 1,
#   ('every', 'house'): 1,
#   ('at', 'every'): 5,
#   ('me', 'at'): 17,
#   ('is', 'me'): 2,
#   ('this', 'is'): 84,
#   ('start', 'this'): 116,
#   ('https://t.co/wacdv6hlh3', 'stop'): 2,
#   ('singapore', 'https://t.co/wacdv6hlh3'): 2,
#   ('@fansofchangi', 'in'): 47,
#   ('-', '@fansofchangi'): 47,
#   ('2', '-'): 29,
#   ('terminal', '2'): 43,
#   ('airport', 'terminal'): 76,
#   ('changi', 'airport'): 84,
#   ('https://t.co/wdri9dd0ww', 'stop'): 1,
#   ('@elviaagxh_', 'https://t.co/wdri9dd0ww'): 1,
#   ('@jeromebleh', '@elviaagxh_'): 1,
#   ('/', '@jeromebleh'): 3,
#   ('singapore', 'w'): 727,
#   ('centre', 'in'): 301,
#   ('shopping', 'centre'): 155,
#   ('northpoint', 'shopping'): 28,
#   ('at', 'northpoint'): 28,
#   ('..', 'stop'): 45,
#   ('it', '..'): 4,
#   ('do', 'it'): 13,
#   ('just', 'do'): 4,
#   ('@nuyayaa', 'just'): 1,
#   ('start', '@nuyayaa'): 1,
#   ('https://t.co/g2enlmzlsc', 'stop'): 97,
#   ('#singapore', 'https://t.co/g2enlmzlsc'): 97,
#   ('in', '#singapore'): 207,
#   ('trending', 'in'): 101,
#   ('now', 'trending'): 99,
#   ('is', 'now'): 106,
#   ('#aldubiyamin3days', 'is'): 1,
#   ('start', '#aldubiyamin3days'): 1,
#   ('https://t.co/7crlmx8sh0', 'stop'): 1,
#   ('@joojoo16535249', 'https://t.co/7crlmx8sh0'): 1,
#   ('@biongtai', '@joojoo16535249'): 2,
#   ('/', '@biongtai'): 3,
#   ('16', 'w'): 2,
#   ("'", '16'): 6,
#   ('3a2', "'"): 2,
#   ('at', '3a2'): 2,
#   ('https://t.co/a7h2nrp4uv', 'stop'): 1,
#   ('singapore', 'https://t.co/a7h2nrp4uv'): 1,
#   ('alpha', 'in'): 1,
#   ('camp', 'alpha'): 1,
#   ('hill', 'camp'): 3,
#   ('mandai', 'hill'): 3,
#   ('at', 'mandai'): 7,
#   ('https://t.co/rc9xdsmxii', 'stop'): 2,
#   ('penawar', 'https://t.co/rc9xdsmxii'): 2,
#   ('bandar', 'penawar'): 6,
#   ('mara', 'bandar'): 3,
#   ('profesional', 'mara'): 3,
#   ('kolej', 'profesional'): 3,
#   ('@', 'kolej'): 3,
#   ('finally', '@'): 2,
#   ('...', 'finally'): 2,
#   ('them', '...'): 2,
#   ('seeing', 'them'): 2,
#   ('not', 'seeing'): 4,
#   ('month', 'not'): 2,
#   ('half', 'month'): 2,
#   ('a', 'half'): 2,
#   ('&', 'a'): 7,
#   ('1', '&'): 4,
#   ('after', '1'): 4,
#   ('start', 'after'): 24,
#   ('#careerarc', 'stop'): 116,
#   ('#hiring', '#careerarc'): 93,
#   ('#businessmgmt', '#hiring'): 9,
#   ('https://t.co/jybjj1jj28', '#businessmgmt'): 1,
#   (':', 'https://t.co/jybjj1jj28'): 2,
#   ('fit', ':'): 35,
#   ('great', 'fit'): 51,
#   ('could', 'be'): 45,
#   ('this', 'could'): 35,
#   ('?', 'this'): 39,
#   ('#singapore', '?'): 50,
#   ('near', '#singapore'): 29,
#   ('#job', 'near'): 35,
#   ('a', '#job'): 35,
#   ('in', 'a'): 90,
#   ('interested', 'in'): 37,
#   ('start', 'interested'): 39,
#   ('https://t.co/ntn2knqwuz', 'stop'): 1,
#   (')', 'https://t.co/ntn2knqwuz'): 1,
#   ('@jeffreytaykh', ')'): 1,
#   ('/', '@jeffreytaykh'): 2,
#   ('island', 'w'): 1,
#   ('paradise', 'island'): 1,
#   ('@', 'paradise'): 1,
#   ('️', '('): 53,
#   ('♥', '️'): 5,
#   ('exhaustedd', '♥'): 1,
#   ('start', 'exhaustedd'): 1,
#   ('https://t.co/dwgwjvwqid', 'stop'): 1,
#   ('singapore', 'https://t.co/dwgwjvwqid'): 1,
#   ('@smrt_singapore', 'in'): 274,
#   ('-', '@smrt_singapore'): 274,
#   (')', '-'): 387,
#   ('ew27', ')'): 23,
#   ('(', 'ew27'): 23,
#   ('station', '('): 234,
#   ('mrt', 'station'): 238,
#   ('lay', 'mrt'): 23,
#   ('boon', 'lay'): 62,
#   ('at', 'boon'): 52,
#   ('https://t.co/mcdrkqndb2', 'stop'): 1,
#   ('johor', 'https://t.co/mcdrkqndb2'): 1,
#   ('langsat', 'in'): 2,
#   ('.', 'langsat'): 5,
#   ('tj', '.'): 2,
#   ('mesh', 'tj'): 2,
#   ('steel', 'mesh'): 2,
#   ('southern', 'steel'): 2,
#   ('at', 'southern'): 2,
#   ('https://t.co/difwbk7uhj', 'stop'): 1,
#   (')', 'https://t.co/difwbk7uhj'): 1,
#   ('bahru', ')'): 16,
#   ('johor', 'bahru'): 1162,
#   ('in', 'johor'): 989,
#   ('cafe', 'in'): 55,
#   ('sds', 'cafe'): 1,
#   ('@', 'sds'): 1,
#   ('meeting', '('): 2,
#   ('lunch', 'meeting'): 1,
#   ('https://t.co/fziy8sdqzr', 'stop'): 1,
#   (')', 'https://t.co/fziy8sdqzr'): 1,
#   ('johor', ')'): 232,
#   ('bahru', ','): 914,
#   ('patah', ','): 4,
#   ('gelang', 'patah'): 5,
#   ('in', 'gelang'): 4,
#   ('residence', 'in'): 9,
#   ('pines', 'residence'): 1,
#   ('the', 'pines'): 1,
#   ('breakfast', '('): 11,
#   ('start', 'breakfast'): 22,
#   ('ending', 'stop'): 3,
#   ('fairytale', 'ending'): 1,
#   ('a', 'fairytale'): 1,
#   ('not', 'a'): 27,
#   ('is', 'not'): 30,
#   ('euro', 'is'): 2,
#   ('the', 'euro'): 9,
#   ('winning', 'the'): 1,
#   ('portugal', 'winning'): 2,
#   ('start', 'portugal'): 18,
#   ('https://t.co/gptkk8jjsg', 'stop'): 2,
#   ('singapore', 'https://t.co/gptkk8jjsg'): 2,
#   ('#singapore', '#hiring'): 35,
#   ('#legal', '#singapore'): 2,
#   ('https://t.co/ukrmuodf3z', '#legal'): 1,
#   ('?', 'https://t.co/ukrmuodf3z'): 1,
#   ('#job', '?'): 28,
#   ('this', '#job'): 73,
#   ('for', 'this'): 62,
#   ('anyone', 'for'): 28,
#   ('recommend', 'anyone'): 28,
#   ('you', 'recommend'): 28,
#   ('can', 'you'): 43,
#   ('start', 'can'): 53,
#   ('https://t.co/1j2zhb3cdm', 'stop'): 2,
#   ('—', 'https://t.co/1j2zhb3cdm'): 2,
#   (')', '—'): 550,
#   ('terminal', ')'): 24,
#   ('ferry', 'terminal'): 29,
#   ('&', 'ferry'): 12,
#   ('cruise', '&'): 13,
#   ('harbourfront', 'cruise'): 12,
#   ('at', 'harbourfront'): 24,
#   ('(', 'at'): 390,
#   ('...', '('): 51,
#   ('end', '...'): 2,
#   ('holiday', 'end'): 2,
#   ('homee', 'holiday'): 2,
#   ('go', 'homee'): 2,
#   ('start', 'go'): 13,
#   ('https://t.co/3e6rf16mnz', 'stop'): 1,
#   ('johor', 'https://t.co/3e6rf16mnz'): 1,
#   ('sentral', 'in'): 63,
#   ('larkin', 'sentral'): 58,
#   ('at', 'larkin'): 53,
#   ('https://t.co/zfhdrgydka', 'stop'): 1,
#   ('crib', 'https://t.co/zfhdrgydka'): 1,
#   ("sean's", 'crib'): 1,
#   ('at', "sean's"): 3,
#   ('https://t.co/i2prhfb10o', 'stop'): 1,
#   ('@lynnlaloy', 'https://t.co/i2prhfb10o'): 1,
#   ('/', '@lynnlaloy'): 1,
#   ('grill', 'in'): 9,
#   ('&', 'grill'): 12,
#   ('steamboat', '&'): 2,
#   ('kapten', 'steamboat'): 1,
#   ('at', 'kapten'): 1,
#   ('...', 'stop'): 68,
#   ('skirt', '...'): 1,
#   ('up', 'skirt'): 1,
#   ('...', 'up'): 1,
#   ('enuf', '...'): 1,
#   ('big', 'enuf'): 1,
#   ('nt', 'big'): 1,
#   ('ass', 'nt'): 1,
#   ('..', 'ass'): 1,
#   ('small', '..'): 1,
#   ('boobs', 'small'): 1,
#   ('..', 'boobs'): 1,
#   ('jobs', '..'): 1,
#   ('blow', 'jobs'): 1,
#   ('..', 'blow'): 1,
#   ('tinder', '..'): 1,
#   ('...', 'tinder'): 1,
#   ('fuck', '...'): 1,
#   ('the', 'fuck'): 16,
#   ('what', 'the'): 14,
#   ('nowadays', 'what'): 1,
#   ('about', 'nowadays'): 1,
#   ('talking', 'about'): 15,
#   ('boys', 'talking'): 1,
#   ('twos', 'boys'): 1,
#   ('sec', 'twos'): 1,
#   ('are', 'sec'): 1,
#   ('wtf', 'are'): 1,
#   ('start', 'wtf'): 14,
#   ('https://t.co/2e66wjdd0i', 'stop'): 1,
#   ('#hfsp', 'https://t.co/2e66wjdd0i'): 1,
#   ('?', '#hfsp'): 1,
#   ('infections', '?'): 1,
#   ('viral', 'infections'): 1,
#   ('fight', 'viral'): 1,
#   ('bacteria', 'fight'): 1,
#   ('do', 'bacteria'): 1,
#   ('how', 'do'): 4,
#   ('.', 'how'): 11,
#   ('direction', '.'): 1,
#   ('unexpected', 'direction'): 1,
#   ('an', 'unexpected'): 2,
#   ('from', 'an'): 1,
#   ('coming', 'from'): 4,
#   ('research', 'coming'): 1,
#   ('exciting', 'research'): 1,
#   (',', 'exciting'): 1,
#   ('crispr', ','): 1,
#   (':', 'crispr'): 1,
#   ('doudna', ':'): 1,
#   ('start', 'doudna'): 1,
#   ('.', 'stop'): 755,
#   ('mind', '.'): 3,
#   ('in', 'mind'): 3,
#   ('you', 'in'): 13,
#   ('keep', 'you'): 2,
#   ('will', 'keep'): 3,
#   ('we', 'will'): 12,
#   ('but', 'we'): 2,
#   ('netherlands', 'but'): 2,
#   ('the', 'netherlands'): 6,
#   ('in', 'the'): 240,
#   ('designers', 'in'): 2,
#   ('for', 'designers'): 2,
#   ('looking', 'for'): 42,
#   ('initially', 'looking'): 2,
#   ('are', 'initially'): 2,
#   ('we', 'are'): 49,
#   (',', 'we'): 30,
#   ('aziz', ','): 2,
#   ('hello', 'aziz'): 2,
#   ('@consult_aziz', 'hello'): 2,
#   ('start', '@consult_aziz'): 2,
#   ('https://t.co/xiny9gqnrc', 'stop'): 1,
#   ('2', 'https://t.co/xiny9gqnrc'): 1,
#   ('@', 'changi'): 38,
#   ('❤', '@'): 14,
#   ('eye', '❤'): 1,
#   ('my', 'eye'): 3,
#   ('of', 'my'): 51,
#   ('apple', 'of'): 1,
#   ('the', 'apple'): 1,
#   ('are', 'the'): 23,
#   ('you', 'are'): 39,
#   ('start', 'you'): 36,
#   ('https://t.co/qpchor6m1e', 'stop'): 2,
#   ('skudai', 'https://t.co/qpchor6m1e'): 2,
#   (',', 'skudai'): 9,
#   ('johor', ','): 26,
#   ('workshop', 'in'): 5,
#   ('cheong', 'workshop'): 2,
#   ('tak', 'cheong'): 2,
#   ('at', 'tak'): 2,
#   ('https://t.co/1x3sxkobxz', 'stop'): 1,
#   ('https://t.co/kdhpy3ka50', 'https://t.co/1x3sxkobxz'): 1,
#   (')', 'https://t.co/kdhpy3ka50'): 1,
#   ('@mato04368008', ')'): 1,
#   ('@danialtwinsatu', '@mato04368008'): 31,
#   ('/', '@danialtwinsatu'): 1,
#   (',', 'singapore'): 317,
#   ('town', ','): 4,
#   ('pines', 'town'): 2,
#   ('tam', 'pines'): 2,
#   ('in', 'tam'): 2,
#   ('palace', 'in'): 2,
#   ("toma's", 'palace'): 2,
#   ('@', "toma's"): 1,
#   ('homy', '('): 1,
#   ('start', 'homy'): 1,
#   ('?', 'stop'): 226,
#   ('estate', '?'): 1,
#   ('real', 'estate'): 1,
#   ('in', 'real'): 3,
#   ('invested', 'in'): 2,
#   ('is', 'invested'): 1,
#   ('he', 'is'): 22,
#   ('be', 'he'): 1,
#   ('it', 'be'): 8,
#   ('cud', 'it'): 1,
#   ('?', 'cud'): 1,
#   ('value', '?'): 1,
#   ('asset', 'value'): 1,
#   ('his', 'asset'): 1,
#   ('in', 'his'): 9,
#   ('.', 'in'): 29,
#   ('6crs', '.'): 1,
#   ('rs', '6crs'): 1,
#   ('lost', 'rs'): 1,
#   ('jaitley', 'lost'): 1,
#   ('y', 'jaitley'): 1,
#   ('wondered', 'y'): 1,
#   ('u', 'wondered'): 1,
#   ('have', 'u'): 2,
#   ('@thewire_in', 'have'): 1,
#   ('@bombaywallah', '@thewire_in'): 1,
#   ('@svaradarajan', '@bombaywallah'): 1,
#   ('start', '@svaradarajan'): 1,
#   ('https://t.co/500mtq1it7', 'stop'): 1,
#   ('johor', 'https://t.co/500mtq1it7'): 1,
#   ('hypermarket', 'in'): 29,
#   ('giant', 'hypermarket'): 30,
#   ('at', 'giant'): 38,
#   ('https://t.co/ylyxwwoaee', 'stop'): 1,
#   ('surprised', 'https://t.co/ylyxwwoaee'): 1,
#   ('be', 'surprised'): 3,
#   ("don't", 'be'): 5,
#   ('u', "don't"): 3,
#   ('towards', 'u'): 1,
#   ('cold', 'towards'): 1,
#   ("i'm", 'cold'): 1,
#   ('if', "i'm"): 7,
#   ('but', 'if'): 4,
#   ('tru', 'but'): 1,
#   ('start', 'tru'): 1,
#   ('https://t.co/qbgg7bbkhv', 'stop'): 1,
#   ('@muzammil411', 'https://t.co/qbgg7bbkhv'): 1,
#   ('/', '@muzammil411'): 1,
#   ('al-alif', 'in'): 3,
#   ('restoran', 'al-alif'): 3,
#   ('at', 'restoran'): 32,
#   ('https://t.co/mdgwjw8x81', 'stop'): 1,
#   ('batam', 'https://t.co/mdgwjw8x81'): 1,
#   ('to', 'batam'): 8,
#   ('wellcome', 'to'): 1,
#   ('@', 'wellcome'): 1,
#   ('youuuuuu', '@'): 1,
#   ('got', 'youuuuuu'): 1,
#   ('haha', 'got'): 1,
#   ('start', 'haha'): 6,
#   ('https://t.co/qyqechmgkw', 'stop'): 2,
#   ('singapore', 'https://t.co/qyqechmgkw'): 2,
#   ('mall', 'in'): 190,
#   ('hougang', 'mall'): 13,
#   ('at', 'hougang'): 68,
#   ('#aug2016volleyball', 'stop'): 5,
#   ('!', '#aug2016volleyball'): 2,
#   ('apologized', '!'): 1,
#   ('she', 'apologized'): 1,
#   ('and', 'she'): 8,
#   ('.', 'and'): 31,
#   ('player', '.'): 3,
#   ('sg', 'player'): 1,
#   ('an', 'sg'): 1,
#   ('to', 'an'): 8,
#   ('facial', 'to'): 1,
#   ('another', 'facial'): 1,
#   ('did', 'another'): 1,
#   ('@michellemorente', 'did'): 1,
#   ('start', '@michellemorente'): 1,
#   ('https://t.co/prikacmu8q', 'stop'): 1,
#   ("murphy's", 'https://t.co/prikacmu8q'): 1,
#   ('@', "murphy's"): 1,
#   ('️', '@'): 96,
#   ('☕', '️'): 29,
#   ('!', '☕'): 2,
#   ('better', '!'): 2,
#   ('everything', 'better'): 1,
#   ('makes', 'everything'): 1,
#   ('coffee', 'makes'): 1,
#   ('start', 'coffee'): 5,
#   ('https://t.co/5dvjc1xxaa', 'stop'): 1,
#   ('…', 'https://t.co/5dvjc1xxaa'): 1,
#   (',', '…'): 46,
#   ('aquarium', ','): 9,
#   ('.', 'aquarium'): 9,
#   ('a', '.'): 16,
#   ('.', 'a'): 23,
#   ('e', '.'): 12,
#   ('.', 'e'): 11,
#   ('s', '.'): 30,
#   ('@', 's'): 8,
#   ('mike_supattrapan', '@'): 1,
#   (':', 'mike_supattrapan'): 1,
#   ('cr', ':'): 3,
#   ('sea', 'cr'): 1,
#   ('blue', 'sea'): 1,
#   ('deep', 'blue'): 1,
#   ('#singapore', 'deep'): 1,
#   ('#aquarium', '#singapore'): 1,
#   ('~', '#aquarium'): 1,
#   ('silhouette', '~'): 1,
#   ('start', 'silhouette'): 1,
#   ('https://t.co/97xvighhgz', 'stop'): 1,
#   ('singapore', 'https://t.co/97xvighhgz'): 1,
#   ('@', 'singapore'): 257,
#   ('photo', '@'): 283,
#   ('a', 'photo'): 285,
#   ('posted', 'a'): 302,
#   ('just', 'posted'): 301,
#   ('start', 'just'): 364,
#   ('https://t.co/d5nhsganap', 'stop'): 1,
#   ('singapore', 'https://t.co/d5nhsganap'): 1,
#   ('scoop', 'in'): 4,
#   ('daily', 'scoop'): 4,
#   ('the', 'daily'): 5,
#   ('at', 'the'): 283,
#   ('oundeh', 'stop'): 1,
#   ('ah', 'oundeh'): 1,
#   ('village', 'ah'): 1,
#   ('holland', 'village'): 17,
#   ('@pritikaaa_', 'holland'): 1,
#   ('start', '@pritikaaa_'): 2,
#   ('https://t.co/liygxzcksz', 'stop'): 2,
#   ('singapore', 'https://t.co/liygxzcksz'): 2,
#   ('itecc', ')'): 4,
#   ('(', 'itecc'): 4,
#   ('court', '('): 3,
#   ('sky', 'court'): 3,
#   ('at', 'sky'): 4,
#   ('https://t.co/adcignp81d', 'stop'): 1,
#   ('singapore', 'https://t.co/adcignp81d'): 1,
#   ('campus', 'in'): 2,
#   ('vanguard', 'campus'): 1,
#   ('at', 'vanguard'): 1,
#   ('https://t.co/uwtcs8sdg3', 'stop'): 2,
#   ('bahru', 'https://t.co/uwtcs8sdg3'): 2,
#   ('malaysia', ','): 8,
#   ('legoland', 'malaysia'): 13,
#   ('@', 'legoland'): 14,
#   ('https://t.co/iqaar9vknt', 'stop'): 1,
#   ('…', 'https://t.co/iqaar9vknt'): 1,
#   ('singapore', '…'): 11,
#   ('.', '@'): 205,
#   ('marauders', '.'): 1,
#   ('the', 'marauders'): 1,
#   ('with', 'the'): 81,
#   ('fun', 'with'): 5,
#   ('much', 'fun'): 4,
#   ('so', 'much'): 76,
#   ('!', 'so'): 16,
#   ('done', '!'): 4,
#   ('duty', 'done'): 1,
#   ('ndp', 'duty'): 1,
#   ('1st', 'ndp'): 1,
#   ('start', '1st'): 4,
#   ('https://t.co/trmhhyybj0', 'stop'): 1,
#   ('claypot', 'https://t.co/trmhhyybj0'): 1,
#   ('geylang', 'claypot'): 2,
#   ('@', 'geylang'): 8,
#   ('#singapore', '@'): 41,
#   ('#geylang', '#singapore'): 1,
#   ('rice', '#geylang'): 1,
#   ('claypot', 'rice'): 2,
#   ('friend', 'claypot'): 1,
#   ('good', 'friend'): 2,
#   ('my', 'good'): 2,
#   (',', 'my'): 19,
#   ('ah', ','): 3,
#   ('start', 'ah'): 2,
#   ('sweet', 'stop'): 1,
#   ('so', 'sweet'): 4,
#   ('being', 'so'): 7,
#   ('is', 'being'): 9,
#   ('qitarah', 'is'): 1,
#   ('start', 'qitarah'): 1,
#   ('guys', 'stop'): 3,
#   ('number', 'guys'): 1,
#   ('my', 'number'): 4,
#   ('has', 'my'): 1,
#   ('model', 'has'): 1,
#   ('f', 'model'): 2,
#   ('&', 'f'): 3,
#   ('a', '&'): 7,
#   ('an', 'a'): 2,
#   ('.', 'an'): 2,
#   ('line', '.'): 4,
#   ('on', 'line'): 3,
#   ('number', 'on'): 1,
#   ('by', 'my'): 5,
#   ('me', 'by'): 7,
#   ('added', 'me'): 1,
#   ('just', 'added'): 1,
#   ('model', 'just'): 1,
#   ('now', 'an'): 1,
#   ("who's", 'now'): 1,
#   ('friend', "who's"): 2,
#   ('old', 'friend'): 2,
#   ('my', 'old'): 5,
#   ('lmao', 'my'): 3,
#   ('start', 'lmao'): 16,
#   ('https://t.co/ed2dmbctt9', 'stop'): 1,
#   ('cineleisure', 'https://t.co/ed2dmbctt9'): 1,
#   ('orchard', 'cineleisure'): 1,
#   ('chicks', 'orchard'): 1,
#   ('&', 'chicks'): 3,
#   ('fish', '&'): 9,
#   ('@', 'fish'): 3,
#   ('#garlicfriedrice', '@'): 1,
#   ('#chargrilledchicken', '#garlicfriedrice'): 1,
#   ('❤', '#chargrilledchicken'): 1,
#   ('start', '❤'): 13,
#   ('https://t.co/geel1udiji', 'stop'): 1,
#   ('carpark', 'https://t.co/geel1udiji'): 1,
#   ('rd', 'carpark'): 3,
#   ('at', 'rd'): 3,
#   ('https://t.co/mmmb6tmjrr', 'stop'): 1,
#   ('—', 'https://t.co/mmmb6tmjrr'): 1,
#   (']', '—'): 307,
#   ('pic', ']'): 299,
#   ('[', 'pic'): 299,
#   ('lagoi', '['): 1,
#   (')', 'lagoi'): 7,
#   ('canopi', ')'): 15,
#   ('the', 'canopi'): 17,
#   ('(', 'the'): 38,
#   ('bintan', '('): 7,
#   ('bay', 'bintan'): 9,
#   ('treasure', 'bay'): 25,
#   ('at', 'treasure'): 15,
#   ('start', 'at'): 83,
#   ('https://t.co/lr91ylaicr', 'stop'): 2,
#   ('—', 'https://t.co/lr91ylaicr'): 2,
#   ('@cinema21', '['): 2,
#   ('at', '@cinema21'): 41,
#   ('shifa', 'at'): 2,
#   ('and', 'shifa'): 2,
#   ('nanda', 'and'): 2,
#   ('with', 'nanda'): 2,
#   ('start', 'with'): 204,
#   ('https://t.co/kften7wpko', 'stop'): 1,
#   ('singapore', 'https://t.co/kften7wpko'): 1,
#   ('lab', 'in'): 4,
#   ('ice', 'lab'): 5,
#   ('at', 'ice'): 5,
#   ('heheh', '.'): 1,
#   ('.', 'heheh'): 1,
#   ('ade', '.'): 1,
#   ('2', 'ade'): 1,
#   ('mcm', '2'): 1,
#   ('fuhh', 'mcm'): 1,
#   ('.', 'fuhh'): 1,
#   ('drama', '.'): 4,
#   ('raya', 'drama'): 1,
#   ('those', 'raya'): 1,
#   ('all', 'those'): 3,
#   ('watch', 'all'): 1,
#   ('start', 'watch'): 4,
#   ('https://t.co/8lnssrovl9', 'stop'): 2,
#   ('https://t.co/py0ytqsuzd', 'https://t.co/8lnssrovl9'): 2,
#   ('trainings', 'https://t.co/py0ytqsuzd'): 2,
#   ('teacher', 'trainings'): 2,
#   ('singapore', 'teacher'): 2,
#   ('muve', 'singapore'): 2,
#   ('start', 'muve'): 2,
#   ('https://t.co/owtkq19egp', 'stop'): 2,
#   (':', 'https://t.co/owtkq19egp'): 2,
#   ('#imwithyoureg', ':'): 2,
#   ('#maga', '#imwithyoureg'): 2,
#   ('#trump201666', '#maga'): 2,
#   ('#indiana', '#trump201666'): 2,
#   ('edt', '#indiana'): 2,
#   ('pm', 'edt'): 2,
#   ('7:30', 'pm'): 2,
#   ('intuesday', '7:30'): 2,
#   (',', 'intuesday'): 2,
#   ('westfield', ','): 1,
#   ('rallyy', 'westfield'): 1,
#   ('president', 'rallyy'): 1,
#   ('for', 'president'): 2,
#   ('trump', 'for'): 2,
#   ('.', 'trump'): 4,
#   ('j', '.'): 4,
#   ('donald', 'j'): 3,
#   ('!', 'donald'): 1,
#   ('start', '!'): 16,
#   ('badlyy', 'stop'): 1,
#   ('soo', 'badlyy'): 1,
#   ('lipkit', 'soo'): 1,
#   ('kylie', 'lipkit'): 2,
#   ('want', 'kylie'): 1,
#   ('i', 'want'): 78,
#   ('start', 'i'): 458,
#   ('boost', 'stop'): 1,
#   ('at', 'boost'): 1,
#   ('work', 'at'): 38,
#   ('you', 'work'): 3,
#   ('long', 'you'): 1,
#   ('how', 'long'): 8,
#   ('know', 'how'): 13,
#   ('she', 'know'): 1,
#   ('does', 'she'): 1,
#   ('lol', 'does'): 1,
#   ('@hxxlxxna_', 'lol'): 1,
#   ('start', '@hxxlxxna_'): 1,
#   ('lolllll', 'stop'): 1,
#   ('like', 'lolllll'): 1,
#   ('chi', 'like'): 1,
#   ('n', 'chi'): 1,
#   ('taiw', 'n'): 1,
#   ('abt', 'taiw'): 1,
#   ('more', 'abt'): 1,
#   ('its', 'more'): 1,
#   ('lolllll', 'its'): 1,
#   ('ig', 'lolllll'): 1,
#   ('vics', 'ig'): 1,
#   ('on', 'vics'): 1,
#   ('but', 'on'): 1,
#   ('start', 'but'): 25,
#   ('https://t.co/z7vsw7v3wb', 'stop'): 2,
#   (')', 'https://t.co/z7vsw7v3wb'): 2,
#   ('@tianhuiiiii', ')'): 2,
#   ('/', '@tianhuiiiii'): 2,
#   ('campus', ')'): 14,
#   ('delta', 'campus'): 12,
#   ('(', 'delta'): 14,
#   ('@psbacademy', '('): 12,
#   ('at', '@psbacademy'): 12,
#   ('tgiffffffff', '('): 2,
#   ('start', 'tgiffffffff'): 2,
#   ('https://t.co/ifonzw247b', 'stop'): 1,
#   ('https://t.co/dzesspdvma', 'https://t.co/ifonzw247b'): 1,
#   (')', 'https://t.co/dzesspdvma'): 1,
#   ('mccafé', 'in'): 62,
#   ('/', 'mccafé'): 62,
#   ("mcdonald's", '/'): 89,
#   ('@', "mcdonald's"): 54,
#   ('?', '('): 32,
#   ('jimat', '?'): 1,
#   ('start', 'jimat'): 1,
#   ('https://t.co/uqszepdbxh', 'stop'): 1,
#   ('@houhuiqing_', 'https://t.co/uqszepdbxh'): 1,
#   ('@dorischx', '@houhuiqing_'): 1,
#   ('/', '@dorischx'): 11,
#   ('@pizzahut_sg', 'in'): 3,
#   ('at', '@pizzahut_sg'): 3,
#   ('lover', '.'): 1,
#   ('tennis', 'lover'): 1,
#   ('a', 'tennis'): 1,
#   ('to', 'be'): 139,
#   ('was', 'to'): 1,
#   ('it', 'was'): 42,
#   ('time', 'it'): 2,
#   ('a', 'time'): 6,
#   ('what', 'a'): 19,
#   (',', 'what'): 10,
#   ('seles', ','): 1,
#   (',', 'seles'): 1,
#   ('sanchez', ','): 1,
#   (',', 'sanchez'): 1,
#   ('sabatini', ','): 1,
#   (',', 'sabatini'): 1,
#   ('martina', ','): 1,
#   ('.', 'martina'): 1,
#   ('graf', '.'): 1,
#   ('steffi', 'graf'): 1,
#   ('undoubtedly', 'steffi'): 1,
#   ('was', 'undoubtedly'): 1,
#   ('champion', 'was'): 1,
#   ('poplar', 'champion'): 1,
#   ('and', 'poplar'): 1,
#   ('charming', 'and'): 2,
#   ('most', 'charming'): 1,
#   ('the', 'most'): 19,
#   ('start', 'the'): 212,
#   ('goals', '.'): 3,
#   ('is', 'goals'): 2,
#   ('hair', 'is'): 1,
#   ('new', 'hair'): 1,
#   ('s', 'new'): 6,
#   ("'", 's'): 287,
#   ('@maisie_williams', "'"): 1,
#   ('start', '@maisie_williams'): 1,
#   ('https://t.co/4fkx445erp', 'stop'): 2,
#   ('@zbiis', 'https://t.co/4fkx445erp'): 2,
#   ('@wreckedaway', '@zbiis'): 2,
#   ('/', '@wreckedaway'): 5,
#   ("mcdonald's", 'in'): 86,
#   ('at', "mcdonald's"): 139,
#   ('https://t.co/iyc16scmdy', 'stop'): 1,
#   ('…', 'https://t.co/iyc16scmdy'): 1,
#   ('#harrysbar', '…'): 1,
#   ('#harrysbarsingapore', '#harrysbar'): 1,
#   ('#wine', '#harrysbarsingapore'): 1,
#   ('road', '#wine'): 1,
#   ('the', 'road'): 4,
#   ('for', 'the'): 194,
#   ('one', 'for'): 6,
#   ('#raffleshotel', 'one'): 1,
#   ('#raffles', '#raffleshotel'): 1,
#   ('to', '#raffles'): 1,
#   ('route', 'to'): 2,
#   ('en', 'route'): 1,
#   ('start', 'en'): 1,
#   ('https://t.co/egz8u0od95', 'stop'): 2,
#   ('1', 'https://t.co/egz8u0od95'): 2,
#   ('pelanduk', '1'): 2,
#   ('at', 'pelanduk'): 2,
#   ('!', 'stop'): 332,
#   ('1', '!'): 11,
#   ('!', '1'): 10,
#   ('11', '!'): 1,
#   ('!', '11'): 1,
#   ('min', '!'): 1,
#   ('w', 'min'): 1,
#   ('abt', 'w'): 1,
#   ('talked', 'abt'): 1,
#   ('mom', 'talked'): 1,
#   ('my', 'mom'): 13,
#   ('wht', 'my'): 1,
#   ('of', 'wht'): 1,
#   ('curious', 'of'): 1,
#   ('effing', 'curious'): 1,
#   ('so', 'effing'): 1,
#   ('im', 'so'): 17,
#   ('start', 'im'): 32,
#   ('friend', 'stop'): 3,
#   ('my', 'friend'): 18,
#   ('beauty', 'my'): 1,
#   ('outer', 'beauty'): 1,
#   ('and', 'outer'): 1,
#   ('inner', 'and'): 1,
#   ('own', 'inner'): 1,
#   ('their', 'own'): 4,
#   ('has', 'their'): 1,
#   ('everyone', 'has'): 3,
#   ('jealous', 'everyone'): 1,
#   ('be', 'jealous'): 2,
#   ('.', 'dont'): 5,
#   ('now', '.'): 35,
#   ('weight', 'now'): 1,
#   ('gaining', 'weight'): 1,
#   ('im', 'gaining'): 1,
#   ('@nuratiqahtaib', 'im'): 1,
#   ('start', '@nuratiqahtaib'): 2,
#   ('https://t.co/bcxkxdv8xx', 'stop'): 1,
#   ('…', 'https://t.co/bcxkxdv8xx'): 1,
#   ('a', '…'): 4,
#   ("that's", 'a'): 6,
#   ('but', "that's"): 2,
#   ('.', 'but'): 45,
#   ('tap', '.'): 1,
#   ('spinal', 'tap'): 1,
#   ('of', 'spinal'): 1,
#   ('think', 'of'): 6,
#   ('me', 'think'): 1,
#   ('made', 'me'): 14,
#   ('which', 'made'): 1,
#   (',', 'which'): 7,
#   ('11', ','): 1,
#   ('to', '11'): 1,
#   ('goes', 'to'): 6,
#   ('selector', 'goes'): 1,
#   ('the', 'selector'): 1,
#   ('.', 'the'): 46,
#   ('phone', '.'): 2,
#   ('landline', 'phone'): 1,
#   ('old', 'landline'): 1,
#   ('start', 'old'): 4,
#   ('https://t.co/zs8xholy5i', 'stop'): 1,
#   ('—', 'https://t.co/zs8xholy5i'): 1,
#   ('mall', ')'): 37,
#   ('kepri', 'mall'): 15,
#   ('at', 'kepri'): 9,
#   ('egidya', 'at'): 1,
#   ('and', 'egidya'): 1,
#   ('sonia', 'and'): 2,
#   ('with', 'sonia'): 2,
#   ('(', 'with'): 454,
#   ('d', '('): 5,
#   ('start', 'd'): 6,
#   ('https://t.co/vwswjfrxmv', 'stop'): 1,
#   ('…', 'https://t.co/vwswjfrxmv'): 1,
#   ('sauvignon', '…'): 1,
#   ('-', 'sauvignon'): 1,
#   ('dishes', '-'): 1,
#   ('popular', 'dishes'): 1,
#   ...},
#  {'https://t.co/b5spzkcswq': 1,
#   'chevrons': 2,
#   'the': 3488,
#   '@': 3717,
#   '#iworkfordell': 1,
#   '#dellpinoys': 1,
#   '.': 4446,
#   '2': 354,
#   'tin': 4,
#   'and': 1936,
#   'charlotte': 1,
#   'for': 1565,
#   'lunch': 92,
#   'welcome': 37,
#   'start': 18613,
#   'https://t.co/fbbt0aqlts': 2,
#   'singapore': 5991,
#   'in': 7790,
#   'rooms': 5,
#   'function': 6,
#   'virgo': 3,
#   'at': 8333,
#   "i'm": 6573,
#   'https://t.co/uxwpuz3w3j': 1,
#   'supermarket': 13,
#   'prime': 8,
#   'bitch': 22,
#   'a': 1850,
#   'be': 543,
#   'dont': 67,
#   'pls': 87,
#   'laptop': 3,
#   'finally': 88,
#   'urgh': 1,
#   '️': 549,
#   '☺': 77,
#   '!': 2885,
#   'care': 42,
#   'take': 110,
#   'you': 1257,
#   'bless': 30,
#   'god': 82,
#   'may': 86,
#   'ahead': 14,
#   'day': 299,
#   'blessed': 21,
#   'have': 400,
#   'aman': 1,
#   'birthday': 181,
#   'happy': 267,
#   '@hersheyyyss': 2,
#   '#supportzakirnaik': 2,
#   'knowledge': 12,
#   'great': 198,
#   'speech': 6,
#   'his': 152,
#   'with': 1456,
#   'world': 147,
#   'around': 73,
#   'peace': 16,
#   'spread': 3,
#   'he': 205,
#   ',': 4594,
#   'speaker': 3,
#   'scholar': 2,
#   'naik': 3,
#   'dr.zakir': 1,
#   'telegram': 7,
#   'on': 765,
#   'stickers': 4,
#   'porn': 2,
#   'me': 686,
#   'spam': 2,
#   'someone': 65,
#   'basket': 1,
#   'https://t.co/9uzwwx0dog': 1,
#   'e4': 1,
#   'gate': 24,
#   'https://t.co/xsz0rrdgdg': 2,
#   ')': 3092,
#   '@amalinaaaaar': 2,
#   '/': 1668,
#   'w': 1201,
#   'johor': 2445,
#   'gudang': 83,
#   'pasir': 188,
#   'hut': 14,
#   'pizza': 44,
#   '(': 3100,
#   'time': 315,
#   'https://t.co/qwvhr7uri2': 2,
#   'west': 216,
#   'airbase': 4,
#   'changi': 193,
#   'https://t.co/vfsfoerft5': 1,
#   '5': 121,
#   'district': 11,
#   'https://t.co/exlo143gqz': 1,
#   'airfield': 3,
#   'sakra': 2,
#   'https://t.co/pfhwmm5o8p': 1,
#   '…': 1318,
#   'most': 49,
#   "singapore's": 6,
#   'of': 1453,
#   'one': 397,
#   'is': 1482,
#   'prvacki': 1,
#   '2006': 1,
#   'linen': 1,
#   'acrylic': 1,
#   '|': 113,
#   'building': 47,
#   "prvacki's": 1,
#   'milenko': 1,
#   'https://t.co/ompqrkvgbe': 2,
#   'masai': 130,
#   'centre': 478,
#   'ict': 5,
#   'cafe': 217,
#   'internet': 19,
#   'already': 74,
#   'sian': 4,
#   'then': 116,
#   'play': 78,
#   'awhile': 11,
#   'after': 143,
#   'like': 438,
#   'go': 433,
#   'pokemon': 208,
#   'than': 94,
#   'better': 72,
#   'version': 9,
#   'ds': 1,
#   'gameboy': 1,
#   'actually': 56,
#   'https://t.co/pksefgq5az': 1,
#   'tho': 32,
#   'honestly': 16,
#   'but': 494,
#   'sorry': 39,
#   'ya': 57,
#   'house': 187,
#   'every': 56,
#   'this': 802,
#   'https://t.co/wacdv6hlh3': 2,
#   '@fansofchangi': 49,
#   '-': 1644,
#   'terminal': 121,
#   'airport': 218,
#   'https://t.co/wdri9dd0ww': 1,
#   '@elviaagxh_': 1,
#   '@jeromebleh': 3,
#   'shopping': 257,
#   'northpoint': 31,
#   '..': 357,
#   'it': 662,
#   'do': 181,
#   'just': 800,
#   '@nuyayaa': 1,
#   'https://t.co/g2enlmzlsc': 97,
#   '#singapore': 538,
#   'trending': 150,
#   'now': 403,
#   '#aldubiyamin3days': 1,
#   'https://t.co/7crlmx8sh0': 1,
#   '@joojoo16535249': 3,
#   '@biongtai': 4,
#   '16': 24,
#   "'": 687,
#   '3a2': 2,
#   'https://t.co/a7h2nrp4uv': 1,
#   'alpha': 1,
#   'camp': 42,
#   'hill': 80,
#   'mandai': 8,
#   'https://t.co/rc9xdsmxii': 2,
#   'penawar': 7,
#   'bandar': 19,
#   'mara': 3,
#   'profesional': 3,
#   'kolej': 3,
#   '...': 586,
#   'them': 88,
#   'seeing': 29,
#   'not': 441,
#   'month': 31,
#   'half': 21,
#   '&': 759,
#   '1': 253,
#   '#careerarc': 116,
#   '#hiring': 227,
#   '#businessmgmt': 18,
#   'https://t.co/jybjj1jj28': 2,
#   ':': 710,
#   'fit': 62,
#   'could': 77,
#   '?': 1227,
#   'near': 49,
#   '#job': 253,
#   'interested': 45,
#   'https://t.co/ntn2knqwuz': 1,
#   '@jeffreytaykh': 2,
#   'island': 94,
#   'paradise': 17,
#   '♥': 16,
#   'exhaustedd': 1,
#   'https://t.co/dwgwjvwqid': 1,
#   '@smrt_singapore': 274,
#   'ew27': 23,
#   'station': 311,
#   'mrt': 337,
#   'lay': 63,
#   'boon': 72,
#   'https://t.co/mcdrkqndb2': 1,
#   'langsat': 8,
#   'tj': 2,
#   'mesh': 2,
#   'steel': 6,
#   'southern': 6,
#   'https://t.co/difwbk7uhj': 1,
#   'bahru': 1188,
#   'sds': 3,
#   'meeting': 23,
#   'https://t.co/fziy8sdqzr': 1,
#   'patah': 5,
#   'gelang': 5,
#   'residence': 25,
#   'pines': 3,
#   'breakfast': 49,
#   'ending': 5,
#   'fairytale': 1,
#   'euro': 27,
#   'winning': 9,
#   'portugal': 86,
#   'https://t.co/gptkk8jjsg': 2,
#   '#legal': 6,
#   'https://t.co/ukrmuodf3z': 1,
#   'anyone': 76,
#   'recommend': 35,
#   'can': 350,
#   'https://t.co/1j2zhb3cdm': 2,
#   '—': 1064,
#   'ferry': 34,
#   'cruise': 15,
#   'harbourfront': 26,
#   'end': 42,
#   'holiday': 42,
#   'homee': 6,
#   'https://t.co/3e6rf16mnz': 1,
#   'sentral': 64,
#   'larkin': 77,
#   'https://t.co/zfhdrgydka': 1,
#   'crib': 77,
#   "sean's": 3,
#   'https://t.co/i2prhfb10o': 1,
#   '@lynnlaloy': 1,
#   'grill': 22,
#   'steamboat': 13,
#   'kapten': 1,
#   'skirt': 5,
#   'up': 288,
#   'enuf': 1,
#   'big': 67,
#   'nt': 7,
#   'ass': 13,
#   'small': 27,
#   'boobs': 1,
#   'jobs': 6,
#   'blow': 3,
#   'tinder': 3,
#   'fuck': 84,
#   'what': 276,
#   'nowadays': 3,
#   'about': 168,
#   'talking': 25,
#   'boys': 41,
#   'twos': 1,
#   'sec': 16,
#   'are': 400,
#   'wtf': 38,
#   'https://t.co/2e66wjdd0i': 1,
#   '#hfsp': 3,
#   'infections': 1,
#   'viral': 1,
#   'fight': 29,
#   'bacteria': 1,
#   'how': 215,
#   'direction': 10,
#   'unexpected': 3,
#   'an': 140,
#   'from': 484,
#   'coming': 67,
#   'research': 4,
#   'exciting': 7,
#   'crispr': 1,
#   'doudna': 1,
#   'mind': 22,
#   'keep': 54,
#   'will': 296,
#   'we': 352,
#   'netherlands': 16,
#   'designers': 2,
#   'looking': 102,
#   'initially': 2,
#   'aziz': 2,
#   'hello': 47,
#   '@consult_aziz': 2,
#   'https://t.co/xiny9gqnrc': 1,
#   '❤': 259,
#   'eye': 21,
#   'my': 1212,
#   'apple': 19,
#   'https://t.co/qpchor6m1e': 2,
#   'skudai': 102,
#   'workshop': 11,
#   'cheong': 8,
#   'tak': 19,
#   'https://t.co/1x3sxkobxz': 1,
#   'https://t.co/kdhpy3ka50': 1,
#   '@mato04368008': 31,
#   '@danialtwinsatu': 35,
#   'town': 65,
#   'tam': 2,
#   'palace': 13,
#   "toma's": 2,
#   'homy': 1,
#   'estate': 4,
#   'real': 42,
#   'invested': 2,
#   'cud': 1,
#   'value': 9,
#   'asset': 1,
#   '6crs': 1,
#   'rs': 3,
#   'lost': 41,
#   'jaitley': 1,
#   'y': 22,
#   'wondered': 1,
#   'u': 344,
#   '@thewire_in': 1,
#   '@bombaywallah': 1,
#   '@svaradarajan': 1,
#   'https://t.co/500mtq1it7': 1,
#   'hypermarket': 30,
#   'giant': 45,
#   'https://t.co/ylyxwwoaee': 1,
#   'surprised': 8,
#   "don't": 191,
#   'towards': 12,
#   'cold': 27,
#   'if': 294,
#   'tru': 3,
#   'https://t.co/qbgg7bbkhv': 1,
#   '@muzammil411': 1,
#   'al-alif': 3,
#   'restoran': 42,
#   'https://t.co/mdgwjw8x81': 1,
#   'batam': 98,
#   'to': 2604,
#   'wellcome': 1,
#   'youuuuuu': 1,
#   'got': 185,
#   'haha': 103,
#   'https://t.co/qyqechmgkw': 2,
#   'mall': 335,
#   'hougang': 102,
#   '#aug2016volleyball': 11,
#   'apologized': 1,
#   'she': 101,
#   'player': 19,
#   'sg': 143,
#   'facial': 4,
#   'another': 66,
#   'did': 88,
#   '@michellemorente': 2,
#   'https://t.co/prikacmu8q': 1,
#   "murphy's": 2,
#   '☕': 51,
#   'everything': 48,
#   'makes': 32,
#   'coffee': 135,
#   'https://t.co/5dvjc1xxaa': 1,
#   'aquarium': 12,
#   'e': 84,
#   's': 402,
#   'mike_supattrapan': 1,
#   'cr': 12,
#   'sea': 40,
#   'blue': 18,
#   'deep': 6,
#   '#aquarium': 1,
#   '~': 101,
#   'silhouette': 1,
#   'https://t.co/97xvighhgz': 1,
#   'photo': 314,
#   'posted': 305,
#   'https://t.co/d5nhsganap': 1,
#   'scoop': 4,
#   'daily': 22,
#   'oundeh': 1,
#   'ah': 50,
#   'village': 90,
#   'holland': 31,
#   '@pritikaaa_': 2,
#   'https://t.co/liygxzcksz': 2,
#   'itecc': 5,
#   'court': 51,
#   'sky': 20,
#   'https://t.co/adcignp81d': 1,
#   'campus': 64,
#   'vanguard': 1,
#   'https://t.co/uwtcs8sdg3': 2,
#   'malaysia': 90,
#   'legoland': 15,
#   'https://t.co/iqaar9vknt': 1,
#   'marauders': 1,
#   'fun': 66,
#   'much': 139,
#   'so': 776,
#   'done': 56,
#   'duty': 8,
#   'ndp': 12,
#   '1st': 34,
#   'https://t.co/trmhhyybj0': 1,
#   'claypot': 8,
#   'geylang': 22,
#   '#geylang': 1,
#   'rice': 33,
#   'friend': 67,
#   'good': 290,
#   'sweet': 45,
#   'being': 79,
#   'qitarah': 1,
#   'guys': 94,
#   'number': 23,
#   'has': 135,
#   'model': 13,
#   'f': 20,
#   'line': 30,
#   'by': 433,
#   'added': 6,
#   "who's": 20,
#   'old': 76,
#   'lmao': 26,
#   'https://t.co/ed2dmbctt9': 1,
#   'cineleisure': 5,
#   'orchard': 148,
#   'chicks': 5,
#   'fish': 40,
#   '#garlicfriedrice': 1,
#   '#chargrilledchicken': 1,
#   'https://t.co/geel1udiji': 1,
#   'carpark': 15,
#   'rd': 36,
#   'https://t.co/mmmb6tmjrr': 1,
#   ']': 340,
#   'pic': 314,
#   '[': 340,
#   'lagoi': 49,
#   'canopi': 17,
#   'bintan': 50,
#   'bay': 313,
#   'treasure': 28,
#   'https://t.co/lr91ylaicr': 2,
#   '@cinema21': 41,
#   'shifa': 2,
#   'nanda': 2,
#   'https://t.co/kften7wpko': 1,
#   'lab': 18,
#   'ice': 59,
#   'heheh': 2,
#   'ade': 9,
#   'mcm': 9,
#   'fuhh': 1,
#   'drama': 11,
#   'raya': 62,
#   'those': 49,
#   'all': 370,
#   'watch': 85,
#   'https://t.co/8lnssrovl9': 2,
#   'https://t.co/py0ytqsuzd': 2,
#   'trainings': 2,
#   'teacher': 11,
#   'muve': 2,
#   'https://t.co/owtkq19egp': 2,
#   '#imwithyoureg': 2,
#   '#maga': 2,
#   '#trump201666': 2,
#   '#indiana': 2,
#   'edt': 3,
#   'pm': 43,
#   '7:30': 2,
#   'intuesday': 2,
#   'westfield': 1,
#   'rallyy': 1,
#   'president': 16,
#   'trump': 23,
#   'j': 30,
#   'donald': 6,
#   'badlyy': 2,
#   'soo': 14,
#   'lipkit': 2,
#   'kylie': 7,
#   'want': 239,
#   'i': 2202,
#   'boost': 3,
#   'work': 256,
#   'long': 86,
#   'know': 164,
#   'does': 33,
#   'lol': 124,
#   '@hxxlxxna_': 1,
#   'lolllll': 2,
#   'chi': 3,
#   'n': 87,
#   'taiw': 1,
#   'abt': 29,
#   'more': 293,
#   'its': 137,
#   'ig': 5,
#   'vics': 1,
#   'https://t.co/z7vsw7v3wb': 2,
#   '@tianhuiiiii': 2,
#   'delta': 15,
#   '@psbacademy': 12,
#   'tgiffffffff': 2,
#   'https://t.co/ifonzw247b': 1,
#   'https://t.co/dzesspdvma': 1,
#   'mccafé': 62,
#   "mcdonald's": 198,
#   'jimat': 1,
#   'https://t.co/uqszepdbxh': 1,
#   '@houhuiqing_': 2,
#   '@dorischx': 15,
#   '@pizzahut_sg': 3,
#   'lover': 2,
#   'tennis': 2,
#   'was': 345,
#   'seles': 1,
#   'sanchez': 1,
#   'sabatini': 1,
#   'martina': 1,
#   'graf': 1,
#   'steffi': 1,
#   'undoubtedly': 1,
#   'champion': 8,
#   'poplar': 1,
#   'charming': 6,
#   'goals': 8,
#   'hair': 36,
#   'new': 218,
#   '@maisie_williams': 1,
#   'https://t.co/4fkx445erp': 2,
#   '@zbiis': 2,
#   '@wreckedaway': 5,
#   'https://t.co/iyc16scmdy': 1,
#   '#harrysbar': 1,
#   '#harrysbarsingapore': 1,
#   '#wine': 2,
#   'road': 141,
#   '#raffleshotel': 2,
#   '#raffles': 1,
#   'route': 4,
#   'en': 1,
#   'https://t.co/egz8u0od95': 2,
#   'pelanduk': 2,
#   '11': 23,
#   'min': 13,
#   'talked': 4,
#   'mom': 32,
#   'wht': 7,
#   'curious': 8,
#   'effing': 2,
#   'im': 153,
#   'beauty': 23,
#   'outer': 2,
#   'inner': 3,
#   'own': 26,
#   'their': 103,
#   'everyone': 57,
#   'jealous': 7,
#   'weight': 6,
#   'gaining': 2,
#   '@nuratiqahtaib': 2,
#   'https://t.co/bcxkxdv8xx': 1,
#   "that's": 60,
#   'tap': 1,
#   'spinal': 1,
#   'think': 110,
#   'made': 98,
#   'which': 51,
#   'goes': 23,
#   'selector': 1,
#   'phone': 27,
#   'landline': 1,
#   'https://t.co/zs8xholy5i': 1,
#   'kepri': 20,
#   'egidya': 1,
#   'sonia': 2,
#   'd': 44,
#   'https://t.co/vwswjfrxmv': 1,
#   'sauvignon': 1,
#   'dishes': 4,
#   'popular': 5,
#   'our': 325,
#   '#thesilverchefbistro': 1,
#   'special': 22,
#   'night': 142,
#   'sunday': 53,
#   'well': 104,
#   'as': 194,
#   'wind': 4,
#   'gone': 10,
#   'fanchant': 2,
#   'https://t.co/hiksnxasca': 2,
#   'gateway': 10,
#   'https://t.co/mgk6rp9jc9': 1,
#   'esplanade': 21,
#   '#lesmiserables': 4,
#   'men': 7,
#   'angry': 8,
#   'song': 52,
#   'singing': 13,
#   'sing': 17,
#   'people': 122,
#   'hear': 26,
#   'https://t.co/ibum0c6yow': 1,
#   'wayyyyy': 1,
#   'pair': 6,
#   'hot': 43,
#   'smoooooking': 1,
#   'nayanthara': 2,
#   'vikram': 5,
#   'wanting': 5,
#   'leave': 19,
#   'poster': 3,
#   '#halenasongteaser': 3,
#   'https://t.co/kwtfzg3py8': 1,
#   '@justinbieber': 8,
#   'boy': 39,
#   'baby': 65,
#   'poor': 10,
#   ':p': 6,
#   'r': 69,
#   'ppl': 30,
#   'some': 128,
#   'gets': 27,
#   'post': 35,
#   'that': 526,
#   'reactions': 3,
#   'love': 280,
#   'however': 2,
#   'hahaha': 92,
#   'https://t.co/itlb6rcuow': 2,
#   'noodle': 36,
#   'home': 174,
#   'top': 50,
#   '#emnomnoms': 2,
#   '#emshootssg': 2,
#   'cheap': 18,
#   'https://t.co/rvyb78p9rk': 2,
#   'vista': 17,
#   'star': 31,
#   '#finance': 17,
#   'https://t.co/fljrqbzkjw': 1,
#   'market': 75,
#   'cloud': 9,
#   'apac': 1,
#   'analyst': 9,
#   'financial': 13,
#   'https://t.co/s6biuktllx': 1,
#   'sands': 102,
#   'marina': 153,
#   'shoppes': 9,
#   '#girlsroaminsg': 1,
#   'https://t.co/pdtqxaoshr': 2,
#   'tg': 8,
#   'https://t.co/xxepoekppu': 2,
#   '@pubsingapore': 6,
#   '#siww': 9,
#   'md': 4,
#   'former': 12,
#   'toh': 5,
#   'michael': 15,
#   'pal': 4,
#   'into': 69,
#   'bumping': 2,
#   '#pokemongo': 33,
#   'again': 119,
#   'geek': 3,
#   'officially': 12,
#   'released': 13,
#   'excited': 31,
#   'really': 165,
#   'walkthroughs': 2,
#   'watching': 91,
#   'https://t.co/bw5co7v9hq': 1,
#   'woodlands': 123,
#   'mookataaaaaa': 1,
#   'https://t.co/niknvialet': 1,
#   'wingzone': 1,
#   'promo': 9,
#   'wing': 7,
#   'per': 3,
#   '50cents': 1,
#   'https://t.co/eblykkc7bj': 1,
#   'collection': 8,
#   'fall': 7,
#   'latest': 111,
#   '’': 76,
#   'label': 4,
#   'part': 40,
#   'black': 42,
#   'accessory': 1,
#   'wallet': 10,
#   'three': 21,
#   'off-white': 1,
#   'https://t.co/ax8pmkysbw': 1,
#   '#vacation': 8,
#   'here': 211,
#   'https://t.co/xoey6j4mgq': 1,
#   'super': 54,
#   'bakso': 5,
#   'https://t.co/plim9sdmvw': 1,
#   '#siww2016': 30,
#   'events': 4,
#   'meetings': 5,
#   'business': 63,
#   'pre-arranged': 1,
#   'presence': 4,
#   'companies': 18,
#   'eu': 4,
#   'allows': 1,
#   '#eugateway': 14,
#   'https://t.co/exihdisnpj': 1,
#   '+': 114,
#   'bugis': 120,
#   'https://t.co/0q5uovk6st': 1,
#   'department': 37,
#   'police': 37,
#   'traffic': 13,
#   'g': 44,
#   't': 95,
#   'season': 18,
#   'him': 80,
#   'games': 26,
#   'afl': 1,
#   'least': 24,
#   'get': 210,
#   'need': 142,
#   'week': 67,
#   'francis': 5,
#   "i'd": 9,
#   '@gebomb79': 1,
#   'https://t.co/o15aajownh': 1,
#   '@cathaycineplex': 29,
#   'independence': 3,
#   '#bastilleday': 3,
#   '#nice06': 2,
#   'suspected': 2,
#   'terrorism': 2,
#   'france': 61,
#   'nice': 97,
#   'crowd': 5,
#   'through': 32,
#   'plows': 2,
#   'truck': 8,
#   'dead': 21,
#   '60': 4,
#   'https://t.co/jedwy9bv93': 1,
#   'jb': 65,
#   'square': 152,
#   'city': 298,
#   'depends': 1,
#   'life': 146,
#   'your': 299,
#   'eat': 74,
#   'out': 271,
#   'should': 90,
#   '@fadly__mohamed': 1,
#   'https://t.co/69gvcz78qv': 1,
#   'hall': 72,
#   'concert': 34,
#   "it's": 217,
#   '10/07': 2,
#   'https://t.co/lh8vzpgjbr': 1,
#   'park': 201,
#   'industrial': 7,
#   'executive': 6,
#   'office': 42,
#   'mild': 2,
#   'clas': 1,
#   'yelahh': 1,
#   'https://t.co/fnx5nqmvnp': 1,
#   'wild': 20,
#   'geo': 1,
#   'nat': 5,
#   '"': 609,
#   'armory': 1,
#   'animals': 1,
#   'https://t.co/hgze9oabhx': 1,
#   'choux': 2,
#   'making': 47,
#   'brenda': 1,
#   'chef': 15,
#   'training': 45,
#   'patissier': 1,
#   'morning': 124,
#   'saturday': 24,
#   'photos': 37,
#   'catch': 46,
#   'https://t.co/holbdcqypg': 1,
#   'eunos': 17,
#   '414': 1,
#   'blk': 370,
#   'bhai': 1,
#   'chota': 1,
#   'https://t.co/38qdcptcuv': 2,
#   'mscp': 2,
#   'drive': 69,
#   'admiralty': 7,
#   '354': 2,
#   'https://t.co/pegjdyzkmk': 2,
#   'future': 29,
#   'challenges': 10,
#   'water': 42,
#   'overcoming': 5,
#   'collaborate': 4,
#   'india': 30,
#   'china': 55,
#   'conf': 2,
#   'technology': 19,
#   'https://t.co/o5hsbodtjl': 1,
#   'pancakes': 1,
#   'paddington': 1,
#   'gymingggg': 1,
#   'why': 209,
#   'https://t.co/2zsm3wj7qz': 1,
#   '7': 100,
#   'before': 104,
#   'grew': 4,
#   'friends': 70,
#   'snakes': 2,
#   'tuan': 2,
#   'mark': 29,
#   'calling': 12,
#   'yall': 8,
#   'hold': 20,
#   'wait': 102,
#   '@syafiqahloves': 1,
#   'y4f1q4h': 1,
#   '$': 74,
#   'euros': 3,
#   'champions': 15,
#   'https://t.co/yxxss1kozt': 1,
#   '#majoroverall': 1,
#   'fighter': 3,
#   'mma': 2,
#   '#onefc': 1,
#   'rodrigo': 1,
#   'coach': 12,
#   'challenge': 15,
#   'grappling': 1,
#   'se': 2,
#   'https://t.co/agmltces9p': 1,
#   '@krystaltsy': 2,
#   '@itespore': 281,
#   'central': 261,
#   'college': 377,
#   'ite': 361,
#   'https://t.co/smllfekegi': 2,
#   'plaza': 103,
#   'https://t.co/lwrb0e8evy': 1,
#   'ubin': 4,
#   'pulau': 14,
#   'point': 193,
#   'highest': 3,
#   'cliff': 2,
#   'edge': 33,
#   'sit': 12,
#   'tracking': 1,
#   'sobbie': 1,
#   'system': 11,
#   'registered': 3,
#   'map': 8,
#   'cos': 34,
#   'yet': 52,
#   "doesn't": 31,
#   '@pamxkay': 1,
#   'harvey': 3,
#   'see': 297,
#   "can't": 135,
#   'loving': 17,
#   'gif': 6,
#   '@suits_usa': 2,
#   'timeline': 7,
#   'niiii': 2,
#   'malam': 4,
#   'dinner': 81,
#   'je': 13,
#   'mcd': 9,
#   'thru': 13,
#   'https://t.co/n4vhxjrwsc': 1,
#   'lah': 26,
#   'heart': 45,
#   'win': 66,
#   'caption': 9,
#   "bf's": 1,
#   'https://t.co/sg12whr7lp': 1,
#   '@awscloud': 1,
#   'acquired': 1,
#   'been': 109,
#   '@cloud9ide': 1,
#   'https://t.co/s2vo01pb19': 2,
#   'fitness': 27,
#   'gym': 41,
#   'pelangi': 3,
#   'gain': 5,
#   'no': 264,
#   'pain': 8,
#   'body': 22,
#   'fat': 15,
#   'burn': 6,
#   'https://t.co/uvk8iebrrt': 1,
#   'payoh': 49,
#   'toa': 49,
#   'zone': 10,
#   'snooker': 2,
#   'https://t.co/e4sn8meg1r': 1,
#   'recipe': 6,
#   'secret': 13,
#   'https://t.co/2lthfqowlu': 1,
#   'lads': 3,
#   'lit': 8,
#   'still': 145,
#   'would': 86,
#   'danga': 22,
#   'thought': 38,
#   'never': 121,
#   'https://t.co/2cvcgigmit': 1,
#   'highway': 9,
#   'nicoll': 7,
#   '2016': 115,
#   'run': 40,
#   'compressport': 5,
#   'pb': 1,
#   'achieved': 2,
#   'yay': 35,
#   '@iamnicocruise': 1,
#   'away': 61,
#   'far': 47,
#   'florida': 1,
#   'guy': 32,
#   'missed': 19,
#   'https://t.co/depqjmw9du': 1,
#   '@hvallz': 4,
#   'thank': 140,
#   '4': 115,
#   'gopro': 5,
#   'binkyboo': 1,
#   'https://t.co/68w9n7yohv': 1,
#   "ahmad's": 1,
#   'https://t.co/22w5ruvtyq': 1,
#   'hawker': 20,
#   'yuan': 8,
#   'ci': 3,
#   'https://t.co/2c0stmm76w': 2,
#   'dianpramitt': 2,
#   'emily': 4,
#   'were': 52,
#   'weeks': 23,
#   'threatened': 1,
#   'grandma': 6,
#   'once': 34,
#   'lift': 6,
#   'peed': 1,
#   '@kreepzville': 3,
#   'https://t.co/on3hvyfqzu': 1,
#   'cosmetics': 1,
#   'lush': 3,
#   'https://t.co/wufu4pzejy': 2,
#   'international': 180,
#   'come': 167,
#   '#cambodia': 2,
#   'https://t.co/i1xyt9fras': 2,
#   'bth': 64,
#   'nadim': 69,
#   'hang': 72,
#   'shandy': 2,
#   'bth-jog': 2,
#   '✈': 50,
#   'jt276': 2,
#   'cute': 58,
#   'knows': 26,
#   'allah': 87,
#   'only': 180,
#   'daughter': 10,
#   'qingai': 1,
#   'didnt': 20,
#   ...})

# %%
b = cst('happy','birthday')
b
# Out:
# "The probability of 'birthday' appearing after 'happy' is: 38.95131%"

# %%
test1,test2 = a
print(test2['happy'])
# Out:
# 267
